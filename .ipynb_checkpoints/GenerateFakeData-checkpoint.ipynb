# %%
import pandas as pd
import numpy as np
import json

# New signed up customer info
columns1 = ['id', 'date', 'cardType', 'region', 'income', 'age', 'previousNumCreditCards']

# New transactions for credit card
columns2 = ['id', 'cardType', 'date', 'transactionType', 'firstName', 'lastName', 'amount', 'balance', 'limit', 'region', 'income', 'age']

# %%
with open('./data/download.json') as json_data:
    d = json.load(json_data)

# %%
df = pd.DataFrame(columns )

# %%
import string
import random
entries = 0

while entries < 5:
    id = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
    entries += 1
    print id
# Out:
# PDBOYWXIZ2
# 7WDJA2MOF0
# 0S6PP1JI2A
# 3Q4TZH3TPD
# AKJVIBX8GT
# E6C9QH33BH
# P0CYA3EYK5
# JF0S5ZM7TY
# O91BQPGJ0S
# B3YWIIV7SJ
# T05PK6IVPY
# XLRYC72KLD
# XH1O2K0IJD
# Z27V11SEI2
# TBFJPU67NG
# 0QY5NZ2N0J
# VE06XAU0B2
# 3XIHXLTV2O
# T36IFEJNXD
# NCKF2O899M
# 2LX1HQPTRN
# PK3HSGUWAA
# AZZJKBXSRI
# T5H9W4D2K8
# Y1P9YHM7DS
# Y3IBQ3JTOD
# RQQB8UKPBD
# YP76T3SCIU
# XGH7SINFI5
# RBNB8CE3VN
# BYEH120O60
# 4W1SNSM4UB
# J8Y48FCG8P
# X3ET56V03W
# WZIV06ODPH
# 2T7TYZRBGP
# 0BWM0LJ4LB
# XDTZ2YVL8P
# 5EBV6VNR8S
# P0C8V2GA5H
# M5EK6WI54V
# IZ2IQP9GXW
# 647RBMP5GP
# 9WAML89O5F
# ZDR3KOUB1S
# C9I0UU1DFI
# ED70XSUTGQ
# URPA9R9UDE
# REWOU21IV2
# 19HC9SY9ZC
# ZZZLQ33FGN
# 5BLWR3F15E
# UR7YFTKIR6
# POZO5WXR6W
# 430ZGVT3OV
# P9NCX59RNT
# LWBOITL75O
# 1S3JWQEW8V
# GEPEW0MS0T
# LR797INRH4
# 8R26KQCBYZ
# JZZ0O6FEAU
# RD9EVXGW89
# CJS8AWDO7Y
# 4YYWN6QR6Y
# JGJW7J4MMY
# GWHS5F64G9
# CUM5R6ZOC7
# UWLFXCD6PF
# UM2HOGEH7N
# SN9BX4SVFO
# DWWLH2K457
# 6OOTBDX5CW
# 06N41ITTK6
# PGH8Y7Y887
# PCB5TQCAAB
# ...
